# %% [markdown]
# ## Smolagents for Financial Name Entity Recognition

# %% [markdown]
# #### 1. First install the packages.

# %%
# %pip install gliner smolagents huggingface_hub
# Out:
# WARNING: Ignoring invalid distribution ~ympy (/home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ympy (/home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages)
# Requirement already satisfied: gliner in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (0.2.16)
# Requirement already satisfied: smolagents in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (1.9.1)
# Requirement already satisfied: torch>=2.0.0 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from gliner) (2.5.1)
# Requirement already satisfied: transformers>=4.38.2 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from gliner) (4.48.1)
# Requirement already satisfied: huggingface_hub>=0.21.4 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from gliner) (0.28.1)
# Requirement already satisfied: tqdm in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from gliner) (4.66.5)
# Requirement already satisfied: onnxruntime in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from gliner) (1.20.1)
# Requirement already satisfied: sentencepiece in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from gliner) (0.2.0)
# Requirement already satisfied: requests>=2.32.3 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from smolagents) (2.32.3)
# Requirement already satisfied: rich>=13.9.4 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from smolagents) (13.9.4)
# Requirement already satisfied: pandas>=2.2.3 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from smolagents) (2.2.3)
# Requirement already satisfied: jinja2>=3.1.4 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from smolagents) (3.1.4)
# Requirement already satisfied: pillow>=11.0.0 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from smolagents) (11.1.0)
# Requirement already satisfied: markdownify>=0.14.1 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from smolagents) (0.14.1)
# Requirement already satisfied: duckduckgo-search>=6.3.7 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from smolagents) (7.2.1)
# Requirement already satisfied: python-dotenv in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from smolagents) (1.0.1)
# Requirement already satisfied: click>=8.1.7 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from duckduckgo-search>=6.3.7->smolagents) (8.1.7)
# Requirement already satisfied: primp>=0.10.0 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from duckduckgo-search>=6.3.7->smolagents) (0.10.0)
# Requirement already satisfied: lxml>=5.3.0 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from duckduckgo-search>=6.3.7->smolagents) (5.3.1)
# Requirement already satisfied: filelock in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from huggingface_hub>=0.21.4->gliner) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from huggingface_hub>=0.21.4->gliner) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from huggingface_hub>=0.21.4->gliner) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from huggingface_hub>=0.21.4->gliner) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from huggingface_hub>=0.21.4->gliner) (4.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from jinja2>=3.1.4->smolagents) (2.1.5)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from markdownify>=0.14.1->smolagents) (4.12.3)
# Requirement already satisfied: six<2,>=1.15 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from markdownify>=0.14.1->smolagents) (1.16.0)
# Requirement already satisfied: numpy>=1.26.0 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from pandas>=2.2.3->smolagents) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from pandas>=2.2.3->smolagents) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from pandas>=2.2.3->smolagents) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from pandas>=2.2.3->smolagents) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from requests>=2.32.3->smolagents) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from requests>=2.32.3->smolagents) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from requests>=2.32.3->smolagents) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from requests>=2.32.3->smolagents) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from rich>=13.9.4->smolagents) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from rich>=13.9.4->smolagents) (2.18.0)
# Requirement already satisfied: networkx in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from torch>=2.0.0->gliner) (3.2.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from torch>=2.0.0->gliner) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from torch>=2.0.0->gliner) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from torch>=2.0.0->gliner) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from torch>=2.0.0->gliner) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from torch>=2.0.0->gliner) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from torch>=2.0.0->gliner) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from torch>=2.0.0->gliner) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from torch>=2.0.0->gliner) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from torch>=2.0.0->gliner) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from torch>=2.0.0->gliner) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from torch>=2.0.0->gliner) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from torch>=2.0.0->gliner) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from torch>=2.0.0->gliner) (3.1.0)
# Requirement already satisfied: setuptools in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from torch>=2.0.0->gliner) (75.8.0)
# Collecting sympy==1.13.1 (from torch>=2.0.0->gliner)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from sympy==1.13.1->torch>=2.0.0->gliner) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from transformers>=4.38.2->gliner) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from transformers>=4.38.2->gliner) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from transformers>=4.38.2->gliner) (0.4.5)
# Requirement already satisfied: coloredlogs in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from onnxruntime->gliner) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from onnxruntime->gliner) (24.12.23)
# Requirement already satisfied: protobuf in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from onnxruntime->gliner) (5.28.2)
# Requirement already satisfied: soupsieve>1.2 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify>=0.14.1->smolagents) (2.5)
# Requirement already satisfied: mdurl~=0.1 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents) (0.1.2)
# Requirement already satisfied: humanfriendly>=9.1 in /home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages (from coloredlogs->onnxruntime->gliner) (10.0)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# WARNING: Ignoring invalid distribution ~ympy (/home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages)
# Installing collected packages: sympy
# WARNING: Ignoring invalid distribution ~ympy (/home/moebius/Projects/HF_Data/venv/lib/python3.12/site-packages)
# Successfully installed sympy
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### 2. Load the libraries we need for the script to work

# %%
from smolagents import CodeAgent, HfApiModel
from huggingface_hub import login, InferenceClient

# %%
import torch, json, os, re, time, random, math
import numpy as np
import pickle

from collections import defaultdict
from datetime import datetime

# %%
import math, h5py

import scipy
from PIL import Image
from scipy import ndimage

import pandas as pd
import os

# %%
import json,os
import nltk
from nltk import tokenize
import torch

# %% [markdown]
# #### 3. Download the Punkt tokenizer model from the Natural Language Toolkit (NLTK) library

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/moebius/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# #### 4. Download the FiNER/139 data set. "finer_tag_names" will have all the categories

# %%
import datasets

finer_train = datasets.load_dataset("nlpaueb/finer-139", split="train")

finer_tag_names = finer_train.features["ner_tags"].feature.names

# %%
text="""Google combines Maps and Waze teams as pressures mount to cut costs
        Rebecca Bellan		
        Google plans to combine the teams working on its Maps product and on Waze, a mapping service that Google acquired in 2013. The merger comes as the search engine giant feels the pressure to cut costs and consolidate operations, reports The Wall Street Journal.
        Waze’s team of 500 employees will fall under Google’s Geo organization, which oversees Maps, Earth and Street View, starting Friday. Neha Parikh, Waze’s current CEO, will leave her role.
        Google told WSJ it plans to keep Waze as a standalone service — Waze is known for its crowdsourcing of en route information like locations of speed cameras, cop cars and roadkill.
        Google also said it didn’t expect any layoffs as part of the reorganization. However, layoffs abound in the tech world, whether you’re a startup or an Amazon. And they often hit the hardest where there are redundancies between teams. Indeed, Google said it expects the restructuring of the different mapping services to reduce overlap in mapmaking.
        Alphabet and Google CEO Sundar Pichai has said he hopes to make Google 20% more productive by running “on fewer resources.” Speaking at Code Conference in September, the executive said the company had become slower due to overhiring and seemed to hint that merging teams that work on overlapping products would help the company stay on top.
        """

# %%
# This should just print the above text.
print(text)
# Out:
# Google combines Maps and Waze teams as pressures mount to cut costs
#         Rebecca Bellan
#         Google plans to combine the teams working on its Maps product and on Waze, a mapping service that Google acquired in 2013. The merger comes as the search engine giant feels the pressure to cut costs and consolidate operations, reports The Wall Street Journal.
#         Waze’s team of 500 employees will fall under Google’s Geo organization, which oversees Maps, Earth and Street View, starting Friday. Neha Parikh, Waze’s current CEO, will leave her role.
#         Google told WSJ it plans to keep Waze as a standalone service — Waze is known for its crowdsourcing of en route information like locations of speed cameras, cop cars and roadkill.
#         Google also said it didn’t expect any layoffs as part of the reorganization. However, layoffs abound in the tech world, whether you’re a startup or an Amazon. And they often hit the hardest where there are redundancies between teams. Indeed, Google said it expects the restructuring of the different mapping services to reduce overlap in mapmaking.
#         Alphabet and Google CEO Sundar Pichai has said he hopes to make Google 20% more productive by running “on fewer resources.” Speaking at Code Conference in September, the executive said the company had become slower due to overhiring and seemed to hint that merging teams that work on overlapping products would help the company stay on top.

# %% [markdown]
# #### 5. Define the labels (entity types) you want to recognize

# %%
labels = ["Source","Financial Metric", "Location", "Date","Organization","Person", "Product", "Percentage", "Monetary Value", "Monetary Value","Duration"]

# %% [markdown]
# #### 6. GLiNER is a way to use ModernBert for NER

# %%
from gliner import GLiNER

# Load the pre-trained GLiNER model with ModernBERT as the backbone
model = GLiNER.from_pretrained("knowledgator/modern-gliner-bi-large-v1.0")


# Predict entities in the text
entities = model.predict_entities(text, labels, threshold=0.3)

# Display the recognized entities
for entity in entities:
    print(f"{entity['text']} => {entity['label']}")
# Out:
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Google => Organization
# Maps => Product
# Waze => Product
# Rebecca Bellan => Person
# Google => Organization
# Maps => Product
# Waze => Product
# Google => Organization
# The Wall Street Journal => Source
# Google => Organization
# Maps => Product
# Earth => Product
# Street View => Product
# Neha Parikh => Person
# Google => Organization
# Google => Organization
# Google => Organization
# Alphabet => Organization
# Google => Organization
# Sundar Pichai => Person
# Google => Organization
# 20% => Percentage
# September => Date

# %% [markdown]
# #### 7. Initialize the SmolAgent on Hugging Face

# %%
hf_token = "<YOUR TOKEN>"

login(hf_token,add_to_git_credential=False)

# %% [markdown]
# #### 8. The Qwen Model is a good start for NER

# %%
repo_id = "Qwen/Qwen2.5-Coder-32B-Instruct"
llm_engine = HfApiModel(model_id=repo_id, provider="together", timeout=3000)

# %% [markdown]
# #### 9. Setup your agent. If you are wondering why its a CodeAgent check out the GAIA multi-agent flow from Huggingface

# %%
agent = CodeAgent(tools=[], model=llm_engine)
agent.run(f"Make a list of entities and explain their context in 1-2 sentences for all of these entites {labels} in this test {text}. Reason step by step what the result of this action could be and add it do the output dataset.")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Make a list of entities and explain their context in 1-2 sentences for all of these entites ['Source',          │
# │ 'Financial Metric', 'Location', 'Date', 'Organization', 'Person', 'Product', 'Percentage', 'Monetary Value',    │
# │ 'Monetary Value', 'Duration'] in this test                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │ Google combines Maps and Waze teams as pressures mount to cut costs | TechCrunch                                │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │ TechCrunch                                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │ plus-bold                                                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │ TechCrunch                                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │ Open Navigation                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │ TechCrunch                                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │ Google combines Maps and Waze teams as pressures mount to cut costs                                             │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                         Rebecca Bellan                                                                          │
# │                                                                                                                 │
# │                                                 10 months                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │ Google plans to combine the teams working on its Maps product and on Waze, a mapping service that Google        │
# │ acquired in 2013. The merger comes as the search engine giant feels the pressure to cut costs and consolidate   │
# │ operations, reports The Wall Street Journal.                                                                    │
# │ Waze’s team of 500 employees will fall under Google’s Geo organization, which oversees Maps, Earth and Street   │
# │ View, starting Friday. Neha Parikh, Waze’s current CEO, will leave her role.                                    │
# │ Google told WSJ it plans to keep Waze as a standalone service — Waze is known for its crowdsourcing of en route │
# │ information like locations of speed cameras, cop cars and roadkill.                                             │
# │ Google also said it didn’t expect any layoffs as part of the reorganization. However, layoffs abound in the     │
# │ tech world, whether you’re a startup or an Amazon. And they often hit the hardest where there are redundancies  │
# │ between teams. Indeed, Google said it expects the restructuring of the different mapping services to reduce     │
# │ overlap in mapmaking.                                                                                           │
# │                                                                                                                 │
# │ Alphabet and Google CEO Sundar Pichai has said he hopes to make Google 20% more productive by running “on fewer │
# │ resources.” Speaking at Code Conference in September, the executive said the company had become slower due to   │
# │ overhiring and seemed to hint that merging teams that work on overlapping products would help the company stay  │
# │ on top.                                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │ . Reason step by step what the result of this action could be and add it do the output dataset.                 │
# │                                                                                                                 │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ──────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Define the text
#   text = """
#   Google combines Maps and Waze teams as pressures mount to cut costs | TechCrunch
#
#   Google plans to combine the teams working on its Maps product and on Waze, a mapping service that Google
#   acquired in 2013. The merger comes as the search engine giant feels the pressure to cut costs and consolidate
#   operations, reports The Wall Street Journal.
#   Waze’s team of 500 employees will fall under Google’s Geo organization, which oversees Maps, Earth and Street
#   View, starting Friday. Neha Parikh, Waze’s current CEO, will leave her role.
#   Google told WSJ it plans to keep Waze as a standalone service — Waze is known for its crowdsourcing of en route
#   information like locations of speed cameras, cop cars and roadkill.
#   Google also said it didn’t expect any layoffs as part of the reorganization. However, layoffs abound in the
#   tech world, whether you’re a startup or an Amazon. And they often hit the hardest where there are redundancies
#   between teams. Indeed, Google said it expects the restructuring of the different mapping services to reduce
#   overlap in mapmaking.
#   Alphabet and Google CEO Sundar Pichai has said he hopes to make Google 20% more productive by running “on fewer
#   resources.” Speaking at Code Conference in September, the executive said the company had become slower due to
#   overhiring and seemed to hint that merging teams that work on overlapping products would help the company stay
#   on top.
#   """
#
#   # Define the entities to extract
#   entities = ['Source', 'Financial Metric', 'Location', 'Date', 'Organization', 'Person', 'Product',
#   'Percentage', 'Monetary Value', 'Monetary Value', 'Duration']
#
#   # Initialize a dictionary to store the entities and their context
#   entity_context = {}
#
#   # Extract entities and their context
#   entity_context['Source'] = "TechCrunch"
#   entity_context['Financial Metric'] = "Productivity"
#   entity_context['Location'] = "Not explicitly mentioned, but likely refers to Google's headquarters or offices"
#   entity_context['Date'] = "10 months ago (from the article's publication date)"
#   entity_context['Organization'] = "Google, Waze, Google's Geo organization"
#   entity_context['Person'] = "Neha Parikh, Sundar Pichai"
#   entity_context['Product'] = "Google Maps, Waze"
#   entity_context['Percentage'] = "20%"
#   entity_context['Monetary Value'] = "Not explicitly mentioned"
#   entity_context['Monetary Value'] = "Not explicitly mentioned"
#   entity_context['Duration'] = "Not explicitly mentioned, but the reorganization starts on Friday"
#
#   # Print the entity context
#   for entity, context in entity_context.items():
#       print(f"{entity}: {context}")
#
#   final_answer(entity_context)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Source: TechCrunch
# Financial Metric: Productivity
# Location: Not explicitly mentioned, but likely refers to Google's headquarters or offices
# Date: 10 months ago (from the article's publication date)
# Organization: Google, Waze, Google's Geo organization
# Person: Neha Parikh, Sundar Pichai
# Product: Google Maps, Waze
# Percentage: 20%
# Monetary Value: Not explicitly mentioned
# Duration: Not explicitly mentioned, but the reorganization starts on Friday
#
# Out - Final answer: {'Source': 'TechCrunch', 'Financial Metric': 'Productivity', 'Location': "Not explicitly
# mentioned, but likely refers to Google's headquarters or offices", 'Date': "10 months ago (from the article's
# publication date)", 'Organization': "Google, Waze, Google's Geo organization", 'Person': 'Neha Parikh, Sundar
# Pichai', 'Product': 'Google Maps, Waze', 'Percentage': '20%', 'Monetary Value': 'Not explicitly mentioned',
# 'Duration': 'Not explicitly mentioned, but the reorganization starts on Friday'}
# [Step 0: Duration 10.79 seconds| Input tokens: 2,447 | Output tokens: 795]
# {'Source': 'TechCrunch',
#  'Financial Metric': 'Productivity',
#  'Location': "Not explicitly mentioned, but likely refers to Google's headquarters or offices",
#  'Date': "10 months ago (from the article's publication date)",
#  'Organization': "Google, Waze, Google's Geo organization",
#  'Person': 'Neha Parikh, Sundar Pichai',
#  'Product': 'Google Maps, Waze',
#  'Percentage': '20%',
#  'Monetary Value': 'Not explicitly mentioned',
#  'Duration': 'Not explicitly mentioned, but the reorganization starts on Friday'}

# %% [markdown]
# #### 10 . That is it already
